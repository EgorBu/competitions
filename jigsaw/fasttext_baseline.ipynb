# %%
import pandas as pd

def subsample(input_path, out_path, nrows=10000):
    data = pd.read_csv(filepath_or_buffer=input_path)
    data = data.loc[:nrows]
    data.to_csv(out_path)
subsample(input_path="input/train.csv.zip", out_path="input/train_small.csv")
subsample(input_path="input/test.csv.zip", out_path="input/test_small.csv")

# %%
# !wc -l input/train_small.csv

# %%
from datetime import datetime

from fasttext_worker import pipeline, LABEL_COLUMNS

# %%
a = """toxic roc_auc: train 0.990277838709 / val 0.97662550916
toxic is done...
severe_toxic roc_auc: train 0.989501424894 / val 0.984578055285
severe_toxic is done...
obscene roc_auc: train 0.993563178503 / val 0.989779498358
obscene is done...
threat roc_auc: train 0.97763049287 / val 0.967464355254
threat is done...
insult roc_auc: train 0.987698897554 / val 0.980488696557
insult is done...
identity_hate roc_auc: train 0.976192523796 / val 0.964747267574
identity_hate is done...
mean roc_auc 0.977280563698
toxic roc_auc: train 0.998784616463 / val 0.953152368841
toxic is done...
severe_toxic roc_auc: train 0.990759923952 / val 0.97709824178
severe_toxic is done...
obscene roc_auc: train 0.996541478346 / val 0.979952192453
obscene is done...
threat roc_auc: train 0.989457913999 / val 0.94175482752
threat is done...
insult roc_auc: train 0.992139718788 / val 0.975762698832
insult is done...
identity_hate roc_auc: train 0.984101904824 / val 0.957167555808
identity_hate is done...
mean roc_auc 0.964147980872
toxic roc_auc: train 0.995213044833 / val 0.972457709524
toxic is done...
severe_toxic roc_auc: train 0.990335090935 / val 0.986932556976
severe_toxic is done...
obscene roc_auc: train 0.995129520469 / val 0.987620791223
obscene is done...
threat roc_auc: train 0.981893025688 / val 0.980535830244
threat is done...
insult roc_auc: train 0.990240649039 / val 0.97712912888
insult is done...
identity_hate roc_auc: train 0.980174904981 / val 0.965284681906
identity_hate is done...
mean roc_auc 0.978326783125
toxic roc_auc: train 0.998397841007 / val 0.958534708167
toxic is done...
severe_toxic roc_auc: train 0.990619282132 / val 0.982539657106
severe_toxic is done...
obscene roc_auc: train 0.996153750095 / val 0.980997458895
obscene is done...
threat roc_auc: train 0.98870136753 / val 0.911701890844
threat is done...
insult roc_auc: train 0.991787340915 / val 0.966713598819
insult is done...
identity_hate roc_auc: train 0.983918854071 / val 0.941133674954
identity_hate is done...
mean roc_auc 0.956936831464
toxic roc_auc: train 0.998241457677 / val 0.962557932756
toxic is done...
severe_toxic roc_auc: train 0.990652867864 / val 0.984735353789
severe_toxic is done...
obscene roc_auc: train 0.996340396241 / val 0.982786486431
obscene is done...
threat roc_auc: train 0.988121765222 / val 0.981669600201
threat is done...
insult roc_auc: train 0.991789361228 / val 0.976452450464
insult is done...
identity_hate roc_auc: train 0.982891342289 / val 0.953384162924
identity_hate is done...
mean roc_auc 0.973597664428
toxic roc_auc: train 0.996463483419 / val 0.973203324865
toxic is done...
severe_toxic roc_auc: train 0.990814514266 / val 0.977409470075
severe_toxic is done...
obscene roc_auc: train 0.995655565463 / val 0.983018881789
obscene is done...
threat roc_auc: train 0.986533636415 / val 0.962455743156
threat is done...
insult roc_auc: train 0.990981331496 / val 0.979670531947
insult is done...
identity_hate roc_auc: train 0.982302387343 / val 0.970557585009
identity_hate is done...
mean roc_auc 0.974385922807
toxic roc_auc: train 0.989602293249 / val 0.972233747052
toxic is done...
severe_toxic roc_auc: train 0.989735196435 / val 0.988415251855
severe_toxic is done...
obscene roc_auc: train 0.993878454484 / val 0.988773214173
obscene is done...
threat roc_auc: train 0.981046262053 / val 0.97710803579
threat is done...
insult roc_auc: train 0.988580825582 / val 0.975919637762
insult is done...
identity_hate roc_auc: train 0.979489628625 / val 0.959558719965
identity_hate is done...
mean roc_auc 0.977001434433
toxic roc_auc: train 0.993276761411 / val 0.972461368501
toxic is done...
severe_toxic roc_auc: train 0.990414689613 / val 0.983949841088
severe_toxic is done...
obscene roc_auc: train 0.994815051755 / val 0.988685204308
obscene is done...
threat roc_auc: train 0.982870368697 / val 0.933542911034
threat is done...
insult roc_auc: train 0.989648629121 / val 0.975638089358
insult is done...
identity_hate roc_auc: train 0.979519842165 / val 0.962213506736
identity_hate is done...
mean roc_auc 0.969415153504
toxic roc_auc: train 0.953780636553 / val 0.948872265498
toxic is done...
severe_toxic roc_auc: train 0.967501589878 / val 0.975715285538
severe_toxic is done...
obscene roc_auc: train 0.969407531129 / val 0.965709115026
obscene is done...
threat roc_auc: train 0.876745011546 / val 0.880985291512
threat is done...
insult roc_auc: train 0.961974507422 / val 0.96117826108
insult is done...
identity_hate roc_auc: train 0.907595098536 / val 0.911328557779
identity_hate is done...
mean roc_auc 0.940631462739
toxic roc_auc: train 0.997437879932 / val 0.96917677595
toxic is done...
severe_toxic roc_auc: train 0.990492442165 / val 0.979935318783
severe_toxic is done...
obscene roc_auc: train 0.99609763903 / val 0.981383845383
obscene is done...
threat roc_auc: train 0.986289775011 / val 0.963220157754
threat is done...
insult roc_auc: train 0.991403185031 / val 0.976488470708
insult is done...
identity_hate roc_auc: train 0.982447094806 / val 0.966821026678
identity_hate is done...
mean roc_auc 0.972837599209
toxic roc_auc: train 0.990336857794 / val 0.968896300367
toxic is done...
severe_toxic roc_auc: train 0.990406290518 / val 0.983290717027
severe_toxic is done...
obscene roc_auc: train 0.995152917622 / val 0.982160376839
obscene is done...
threat roc_auc: train 0.985808777156 / val 0.950400036665
threat is done...
insult roc_auc: train 0.989461958733 / val 0.971722561714
insult is done...
identity_hate roc_auc: train 0.981074950644 / val 0.972446745876
identity_hate is done...
mean roc_auc 0.971486123081
toxic roc_auc: train 0.998826049336 / val 0.95949503434
toxic is done...
severe_toxic roc_auc: train 0.990357151795 / val 0.979998995631
severe_toxic is done...
obscene roc_auc: train 0.996293354455 / val 0.980921308254
obscene is done...
threat roc_auc: train 0.988440425799 / val 0.936431220923
threat is done...
insult roc_auc: train 0.9920719896 / val 0.963925181859
insult is done...
identity_hate roc_auc: train 0.983786571038 / val 0.945839242656
identity_hate is done...
mean roc_auc 0.96110183061
toxic roc_auc: train 0.981225127657 / val 0.969451217288
toxic is done...
severe_toxic roc_auc: train 0.986233464836 / val 0.987225497736
severe_toxic is done...
obscene roc_auc: train 0.98852878787 / val 0.98715353742
obscene is done...
threat roc_auc: train 0.955240266913 / val 0.9802088665
threat is done...
insult roc_auc: train 0.981713748349 / val 0.97304109622
insult is done...
identity_hate roc_auc: train 0.965136032392 / val 0.959251028015
identity_hate is done...
mean roc_auc 0.976055207196
toxic roc_auc: train 0.972035524211 / val 0.965614729935
toxic is done...
severe_toxic roc_auc: train 0.98065155723 / val 0.983626855601
severe_toxic is done...
obscene roc_auc: train 0.982193887312 / val 0.982728388119
obscene is done...
threat roc_auc: train 0.928102579162 / val 0.909762073684
threat is done...
insult roc_auc: train 0.975060931551 / val 0.972518069728
insult is done...
identity_hate roc_auc: train 0.946921790974 / val 0.941538196233
identity_hate is done...
mean roc_auc 0.959298052217
toxic roc_auc: train 0.995790267792 / val 0.969200441816
toxic is done...
severe_toxic roc_auc: train 0.990407097204 / val 0.985415267136
severe_toxic is done...
obscene roc_auc: train 0.995852781565 / val 0.9808508358
obscene is done...
threat roc_auc: train 0.986976622377 / val 0.973835716003
threat is done...
insult roc_auc: train 0.990931171843 / val 0.975981154471
insult is done...
identity_hate roc_auc: train 0.982713015263 / val 0.958735135317
identity_hate is done...
mean roc_auc 0.974003091757
toxic roc_auc: train 0.994840037793 / val 0.97076787542
toxic is done...
severe_toxic roc_auc: train 0.990218228642 / val 0.98205515943
severe_toxic is done...
obscene roc_auc: train 0.995082733795 / val 0.983347851156
obscene is done...
threat roc_auc: train 0.984215226285 / val 0.976782491235
threat is done...
insult roc_auc: train 0.990094972574 / val 0.976552855853
insult is done...
identity_hate roc_auc: train 0.981090167529 / val 0.965568406047
identity_hate is done...
mean roc_auc 0.97584577319
toxic roc_auc: train 0.999003621201 / val 0.947848784006
toxic is done...
severe_toxic roc_auc: train 0.990666398305 / val 0.982139134916
severe_toxic is done...
obscene roc_auc: train 0.996446228117 / val 0.97285981291
obscene is done...
threat roc_auc: train 0.989369746813 / val 0.952239732883
threat is done...
insult roc_auc: train 0.992195878077 / val 0.960151954227
insult is done...
identity_hate roc_auc: train 0.984887784332 / val 0.912085463216
identity_hate is done...
mean roc_auc 0.954554147026
toxic roc_auc: train 0.997343704978 / val 0.958214628747
toxic is done...
severe_toxic roc_auc: train 0.990190040658 / val 0.991057522833
severe_toxic is done...
obscene roc_auc: train 0.996171999598 / val 0.976320025586
obscene is done...
threat roc_auc: train 0.987831367432 / val 0.921016469701
threat is done...
insult roc_auc: train 0.99140999527 / val 0.968384725858
insult is done...
identity_hate roc_auc: train 0.983495849942 / val 0.923381932219
identity_hate is done...
mean roc_auc 0.956395884157
toxic roc_auc: train 0.998035084467 / val 0.966735186978
toxic is done...
severe_toxic roc_auc: train 0.990314474852 / val 0.983814588434
severe_toxic is done...
obscene roc_auc: train 0.99617962926 / val 0.978669394137
obscene is done...
threat roc_auc: train 0.985664508598 / val 0.9721366608
threat is done...
insult roc_auc: train 0.991594701681 / val 0.969000104937
insult is done...
identity_hate roc_auc: train 0.982629404269 / val 0.931717610252
identity_hate is done...
mean roc_auc 0.96701225759
toxic roc_auc: train 0.994005123801 / val 0.973997965404
toxic is done...
severe_toxic roc_auc: train 0.989770037822 / val 0.983158097152
severe_toxic is done...
obscene roc_auc: train 0.99480405928 / val 0.985821968782
obscene is done...
threat roc_auc: train 0.980546823778 / val 0.955086120191
threat is done...
insult roc_auc: train 0.989659610354 / val 0.98078027481
insult is done...
identity_hate roc_auc: train 0.978849106462 / val 0.963492014383
identity_hate is done...
mean roc_auc 0.97372274012
toxic roc_auc: train 0.974557902407 / val 0.970305017102
toxic is done...
severe_toxic roc_auc: train 0.986023068993 / val 0.971843015301
severe_toxic is done...
obscene roc_auc: train 0.985360382114 / val 0.983467906266
obscene is done...
threat roc_auc: train 0.942387904889 / val 0.955021022085
threat is done...
insult roc_auc: train 0.977576844752 / val 0.974146473948
insult is done...
identity_hate roc_auc: train 0.958720206933 / val 0.962725168665
identity_hate is done...
mean roc_auc 0.969584767228
toxic roc_auc: train 0.990002484803 / val 0.971572199012
toxic is done...
severe_toxic roc_auc: train 0.98948428965 / val 0.984354595151
severe_toxic is done...
obscene roc_auc: train 0.993468963747 / val 0.989509486822
obscene is done...
threat roc_auc: train 0.976484884537 / val 0.95271927067
threat is done...
insult roc_auc: train 0.987568697087 / val 0.98075902026
insult is done...
identity_hate roc_auc: train 0.975935647514 / val 0.977769819367
identity_hate is done...
mean roc_auc 0.976114065214
toxic roc_auc: train 0.99518150771 / val 0.970547415279
toxic is done...
severe_toxic roc_auc: train 0.990056641608 / val 0.990263316063
severe_toxic is done...
obscene roc_auc: train 0.995503355657 / val 0.988286466802
obscene is done...
threat roc_auc: train 0.98285241984 / val 0.962342461165
threat is done...
insult roc_auc: train 0.990419910295 / val 0.98254424303
insult is done...
identity_hate roc_auc: train 0.980747626056 / val 0.970448569963
identity_hate is done...
mean roc_auc 0.97740541205
toxic roc_auc: train 0.992830403365 / val 0.965547148867
toxic is done...
severe_toxic roc_auc: train 0.990234016669 / val 0.982017337188
severe_toxic is done...
obscene roc_auc: train 0.995395970709 / val 0.983866973628
obscene is done...
threat roc_auc: train 0.983034788492 / val 0.965791126686
threat is done...
insult roc_auc: train 0.990045367143 / val 0.974977394342
insult is done...
identity_hate roc_auc: train 0.981611100159 / val 0.955726943407
identity_hate is done...
mean roc_auc 0.97132115402
toxic roc_auc: train 0.993870348628 / val 0.972659514895
toxic is done...
severe_toxic roc_auc: train 0.989889294592 / val 0.989711184105
severe_toxic is done...
obscene roc_auc: train 0.994816644836 / val 0.985405896388
obscene is done...
threat roc_auc: train 0.978822348856 / val 0.97745480578
threat is done...
insult roc_auc: train 0.989724802969 / val 0.977785013676
insult is done...
identity_hate roc_auc: train 0.979095025662 / val 0.964891003217
identity_hate is done...
mean roc_auc 0.977984569677
toxic roc_auc: train 0.995061753762 / val 0.968424787913
toxic is done...
severe_toxic roc_auc: train 0.990214482129 / val 0.974187137802
severe_toxic is done...
obscene roc_auc: train 0.995276097602 / val 0.986502898984
obscene is done...
threat roc_auc: train 0.982546642769 / val 0.95679445309
threat is done...
insult roc_auc: train 0.990138704223 / val 0.981735407761
insult is done...
identity_hate roc_auc: train 0.98011441175 / val 0.965691487733
identity_hate is done...
mean roc_auc 0.972222695547
toxic roc_auc: train 0.989093531288 / val 0.973340960416
toxic is done...
severe_toxic roc_auc: train 0.988559394287 / val 0.987590596911
severe_toxic is done...
obscene roc_auc: train 0.992566691329 / val 0.984545539566
obscene is done...
threat roc_auc: train 0.975025026369 / val 0.968895989902
threat is done...
insult roc_auc: train 0.986573433908 / val 0.979006112877
insult is done...
identity_hate roc_auc: train 0.973585047052 / val 0.969038235399
identity_hate is done...
mean roc_auc 0.977069572512
toxic roc_auc: train 0.994743581678 / val 0.972018596426
toxic is done...
severe_toxic roc_auc: train 0.990210909856 / val 0.982122555674
severe_toxic is done...
obscene roc_auc: train 0.995166115471 / val 0.987805177192
obscene is done...
threat roc_auc: train 0.982974969641 / val 0.956606110133
threat is done...
insult roc_auc: train 0.990235424172 / val 0.979635622983
insult is done...
identity_hate roc_auc: train 0.979481502907 / val 0.976668934174
identity_hate is done...
mean roc_auc 0.97580949943
toxic roc_auc: train 0.989971804161 / val 0.97083436052
toxic is done...
severe_toxic roc_auc: train 0.989056529975 / val 0.988837805945
severe_toxic is done...
obscene roc_auc: train 0.99299259263 / val 0.985119746903
obscene is done...
threat roc_auc: train 0.975452469576 / val 0.975690576705
threat is done...
insult roc_auc: train 0.987071660692 / val 0.979670225051
insult is done...
identity_hate roc_auc: train 0.974769975846 / val 0.966140518036
identity_hate is done...
mean roc_auc 0.97771553886
toxic roc_auc: train 0.982998214674 / val 0.971157216815
toxic is done...
severe_toxic roc_auc: train 0.986761944271 / val 0.98396527405
severe_toxic is done...
obscene roc_auc: train 0.990021123929 / val 0.982606828968
obscene is done...
threat roc_auc: train 0.96427629709 / val 0.967273830557
threat is done...
insult roc_auc: train 0.98279929633 / val 0.976512000269
insult is done...
identity_hate roc_auc: train 0.967489173831 / val 0.966812777443
identity_hate is done...
mean roc_auc 0.97472132135
toxic roc_auc: train 0.996230031901 / val 0.966214049472
toxic is done...
severe_toxic roc_auc: train 0.990187087966 / val 0.989928152411
severe_toxic is done...
obscene roc_auc: train 0.995741923984 / val 0.984563932069
obscene is done...
threat roc_auc: train 0.983740167185 / val 0.93428434158
threat is done...
insult roc_auc: train 0.991073916302 / val 0.97364506172
insult is done...
identity_hate roc_auc: train 0.98146538747 / val 0.968754335173
identity_hate is done...
mean roc_auc 0.969564978738
toxic roc_auc: train 0.981554745811 / val 0.97146576282
toxic is done...
severe_toxic roc_auc: train 0.986943991526 / val 0.982976285498
severe_toxic is done...
obscene roc_auc: train 0.989675219283 / val 0.983233761589
obscene is done...
threat roc_auc: train 0.959276328327 / val 0.956076013735
threat is done...
insult roc_auc: train 0.982325755238 / val 0.976142501851
insult is done...
identity_hate roc_auc: train 0.96808257891 / val 0.959106751556
identity_hate is done...
mean roc_auc 0.971500179508
toxic roc_auc: train 0.994038641476 / val 0.970633630933
toxic is done...
severe_toxic roc_auc: train 0.990087565124 / val 0.989747397724
severe_toxic is done...
obscene roc_auc: train 0.99510096256 / val 0.984608277225
obscene is done...
threat roc_auc: train 0.981803683971 / val 0.966226476677
threat is done...
insult roc_auc: train 0.989843105516 / val 0.979083676578
insult is done...
identity_hate roc_auc: train 0.979128649347 / val 0.975976389416
identity_hate is done...
mean roc_auc 0.977712641426
toxic roc_auc: train 0.998838488014 / val 0.958917552724
toxic is done...
severe_toxic roc_auc: train 0.990846821579 / val 0.982553531036
severe_toxic is done...
obscene roc_auc: train 0.996592472444 / val 0.975189096523
obscene is done...
threat roc_auc: train 0.989668667518 / val 0.927357087497
threat is done...
insult roc_auc: train 0.992240810096 / val 0.962098433233
insult is done...
identity_hate roc_auc: train 0.984708466077 / val 0.948084666793
identity_hate is done...
mean roc_auc 0.959033394634
toxic roc_auc: train 0.988323026978 / val 0.972144579702
toxic is done...
severe_toxic roc_auc: train 0.989182743123 / val 0.984982140486
severe_toxic is done...
obscene roc_auc: train 0.993257298371 / val 0.987916382165
obscene is done...
threat roc_auc: train 0.979503069181 / val 0.946626038358
threat is done...
insult roc_auc: train 0.987616249602 / val 0.976736140255
insult is done...
identity_hate roc_auc: train 0.97611253033 / val 0.973833902162
identity_hate is done...
mean roc_auc 0.973706530521
toxic roc_auc: train 0.99652227623 / val 0.969292327165
toxic is done...
severe_toxic roc_auc: train 0.990636380892 / val 0.981743972663
severe_toxic is done...
obscene roc_auc: train 0.995839348759 / val 0.986163569196
obscene is done...
threat roc_auc: train 0.984584981726 / val 0.970222774171
threat is done...
insult roc_auc: train 0.991039598756 / val 0.97622761518
insult is done...
identity_hate roc_auc: train 0.981746721952 / val 0.961064243997
identity_hate is done...
mean roc_auc 0.974119083729
toxic roc_auc: train 0.996908384529 / val 0.97264437441
toxic is done...
severe_toxic roc_auc: train 0.990796781323 / val 0.984645917204
severe_toxic is done...
obscene roc_auc: train 0.995713287001 / val 0.98397317274
obscene is done...
threat roc_auc: train 0.986128558201 / val 0.954031138697
threat is done...
insult roc_auc: train 0.990956201758 / val 0.97605925309
insult is done...
identity_hate roc_auc: train 0.98187679705 / val 0.9548359795
identity_hate is done...
mean roc_auc 0.971031639273
toxic roc_auc: train 0.992566744826 / val 0.969973874781
toxic is done...
severe_toxic roc_auc: train 0.990231578861 / val 0.978371579944
severe_toxic is done...
obscene roc_auc: train 0.995458718556 / val 0.984893377011
obscene is done...
threat roc_auc: train 0.985076493628 / val 0.956033566785
threat is done...
insult roc_auc: train 0.990107348787 / val 0.971682720562
insult is done...
identity_hate roc_auc: train 0.98159463441 / val 0.958510714591
identity_hate is done...
mean roc_auc 0.969910972279
""".split("\n")
roc_aucs = [line for line in a if "mean roc_auc" in line]
best = 0
for line in roc_aucs:
    best = max(float(line.split()[2]), best)
best
# Out:
# 0.978326783125

# %%
args ={}

args["train_path"] = "input/train_small.csv"
args["test_path"] = "input/test_small.csv"
args["train_path"] = "input/train.csv.zip"
args["test_path"] = "input/test.csv.zip"
args["n_splits"] = 10

args["save_proba"] = "probas/"

args["supervised_input"] = "output/train_small_fasttext.txt"

args["supervised_output"] = "model"
args["supervised_lr"] = 0.1
args["supervised_lrUpdateRate"] = 5
args["supervised_dim"] = 150
args["supervised_ws"] = 5
args["supervised_epoch"] = 10
args["supervised_minCount"] = 5
args["supervised_neg"] = 5
args["supervised_wordNgrams"] = 2
args["supervised_thread"] = 4
args["supervised_label"] = "__label__"
args["supervised_minn"] = 3
args["supervised_maxn"] = 7
# args["supervised_pretrainedVectors"] = "input/crawl-300d-2M.vec"

# %%
roc_auc = pipeline(args)
# Out:
# /home/egor/workspace/kaggle/jigsaw/fasttext_worker.py:134: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   train["fasttext_label_" + col][train[col] == 1] += (args["supervised_label"] + col + " ")
# /home/egor/workspace/kaggle/jigsaw/fasttext_worker.py:140: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   train["fasttext_label_NONE"][mask] += (args["supervised_label"] + "NONE" + " ")
# /home/egor/workspace/kaggle/jigsaw/fasttext_worker.py:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# ...

# %%
import glob

import pandas as pd
import numpy as np


train = pd.read_csv(args["train_path"])
test = pd.read_csv(args["test_path"])

def get_features(path):
    data = pd.read_pickle(path)
    columns = [col for col in list(data) if "_proba_" in col]
    return data[columns].as_matrix()

train_paths = [path for path in glob.glob(args["save_proba"] + "*") if "train" in path]
test_paths = [path for path in glob.glob(args["save_proba"] + "*") if "test" in path]

train_features = np.hstack([get_features(path) for path in train_paths])
train_labels = train[LABEL_COLUMNS].as_matrix()

test_features = np.hstack([get_features(path) for path in test_paths])

# %%
from sklearn.ensemble import ExtraTreesClassifier
from sklearn.metrics import roc_auc_score
from sklearn.model_selection import KFold

def fix_pred(probas):
    return np.hstack(proba[:, 1][:, np.newaxis] for proba in probas)
        

N_SPLITS = 10

kfold = KFold(n_splits=N_SPLITS)
roc_aucs = []
train_pred = np.zeros(train_labels.shape)
test_pred = np.zeros((test_features.shape[0], train_labels.shape[1]))
for i, (train_index, val_index) in enumerate(kfold.split(train)):
    print("Fold %s in progress..." % i)
    train_features_ = train_features[train_index, :]
    train_labels_ = train_labels[train_index, :]
    val_features_ = train_features[val_index, :]
    val_labels_ = train_labels[val_index, :]
    
    model = ExtraTreesClassifier(min_samples_leaf=10)
    model.fit(train_features_, train_labels_)
    print(roc_auc_score(train_labels_, fix_pred(model.predict_proba(train_features_))))
    print(roc_auc_score(val_labels_, fix_pred(model.predict_proba(val_features_))))
    
    train_pred += fix_pred(model.predict_proba(train_features))
    test_pred += fix_pred(model.predict_proba(test_features))
    print("Fold %s completed" % i)

train_pred = train_pred / N_SPLITS
test_pred = test_pred / N_SPLITS

# %%
for i, label in enumerate(LABEL_COLUMNS):
    test[label] = test_pred[:, i]

output = "output/%s-fasttext-baseline-submission.txt" % datetime.now()
cols = ["id"] + LABEL_COLUMNS
test[cols].to_csv(output, sep=",", index=False, quotechar=" ", float_format="%.16f")

# %%
model.classes_

# %%
test

# %%
sum(roc_aucs) / len(roc_aucs)
# public score  0.9696

# %%
for label in LABEL_COLUMNS:
    labels_ = [label + "_proba_" + str(i) for i in range(len(roc_aucs))]
    test[label + "_proba"] = test[labels_].sum(axis=1) / len(roc_aucs)
test[[label + "_proba" for label in LABEL_COLUMNS]].head()

# %%
test[LABEL_COLUMNS] = test[[label + "_proba" for label in LABEL_COLUMNS]].clip(0+1e12, 1-1e12)

""" hyperparameters
args.train_path = "input/train.csv.zip"
args.test_path = "input/test.csv.zip"
args.train_fasttext = "output/train_fasttext.txt"
args.supervised_output = "model"
args.n_splits = 10

args.supervised_lr = 0.1
args.supervised_lr_update_rate = 30
args.supervised_dim = 50
args.supervised_ws = 5
args.supervised_epoch = 200
args.supervised_min_count = 1
args.supervised_neg = 5
args.supervised_word_ngrams = 1
args.supervised_thread = 4"""
output = "output/%s-fasttext-baseline-submission.txt" % datetime.now()
cols = ["id"] + LABEL_COLUMNS
test[cols].to_csv(output, sep=",", index=False, quotechar=" ", float_format="%.16f")
